# %%
from ultralytics import YOLO
import os
import torch
from IPython.display import Image
from helpers.helpers import extract_frames

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# # Model training

# %%
pretrained = YOLO('../models/yolov10m.pt')

# %%
pretrained.train(data="/mnt/DL/Projects/pingpong/notebooks/training/datasets/tennis_ball_ds/tennis_ball_ds/data.yaml", epochs=1000, device='cuda')
# Out:
# Ultralytics YOLOv8.2.78 🚀 Python-3.8.0 torch-2.4.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3080 Ti, 12288MiB)
# ...

# %%
model = YOLO('./runs/detect/train5/weights/best.pt')

# %%
model.predict('../../video/singles_finals.mp4',stream=True, save=True)
# Out:
# <generator object BasePredictor.stream_inference at 0x7f6a5078eeb0>

# %%
# try sahi

# %%
from sahi import AutoDetectionModel

detection_model = AutoDetectionModel.from_pretrained(
    model_type="yolov8",
    model_path='./runs/detect/train5/weights/best.pt',
    confidence_threshold=0.3,
    device="cuda:0",  # or 'cuda:0'
)

# %%
extract_frames('/mnt/DL/Projects/pingpong/video/singles_finals.mp4', output_dir='../../video/singles')
# Out:
# "The output directory isn't empty."

# %%
from sahi.predict import get_prediction

# With an image path
result = get_prediction("/mnt/DL/Projects/pingpong/video/singles/03081.jpg", detection_model)

# %%
result.export_visuals(export_dir="demo_data/")
Image("demo_data/prediction_visual.png")
